# %%
import shap
import pickle

# %%
with open("shap_values_hazard-category_baseline.pkl", "rb") as f:
    shap_values = pickle.load(f)
shap.plots.text(shap_values[0,:,2], grouping_threshold=0.3)
# Out:
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.490897767947544%" y1="33" x2="49.490897767947544%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.490897767947544%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><line x1="39.36138420194659%" y1="33" x2="39.36138420194659%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.36138420194659%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="29.231870635945633%" y1="33" x2="29.231870635945633%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.231870635945633%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="19.102357069944677%" y1="33" x2="19.102357069944677%" y2="37" style="stroke:rgb(150,150,150);stroke-width:
# ...

# %%
with open("shap_values_hazard-category_contextual_words.pkl", "rb") as f:
    shap_values = pickle.load(f)
shap.plots.text(shap_values[0,:,2], grouping_threshold=0.3)
# Out:
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="40.80712901834779%" y1="33" x2="40.80712901834779%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="40.80712901834779%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="19.82733411144873%" y1="33" x2="19.82733411144873%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.82733411144873%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="61.786923925246846%" y1="33" x2="61.786923925246846%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="61.786923925246846%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="82.76671883214591%" y1="33" x2="82.76671883214591%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /
# ...

# %%
with open("shap_values_hazard_baseline.pkl", "rb") as f:
    shap_values = pickle.load(f)

shap.plots.text(shap_values[0,:,70], grouping_threshold=0.3)
# Out:
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.29174867361875%" y1="33" x2="50.29174867361875%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.29174867361875%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="39.7393557813751%" y1="33" x2="39.7393557813751%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.7393557813751%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="29.186962889131454%" y1="33" x2="29.186962889131454%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.186962889131454%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="18.634569996887805%" y1="33" x2="18.634569996887805%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><
# ...

# %%
with open("shap_values_hazard_contextual_words.pkl", "rb") as f:
    shap_values = pickle.load(f)

shap.plots.text(shap_values[0,:,70], grouping_threshold=0.3)
# Out:
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="46.02450131842624%" y1="33" x2="46.02450131842624%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="46.02450131842624%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">4</text><line x1="29.847463038952565%" y1="33" x2="29.847463038952565%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.847463038952565%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="13.67042475947889%" y1="33" x2="13.67042475947889%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="13.67042475947889%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="62.20153959789991%" y1="33" x2="62.20153959789991%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" />
# ...

# %%
# %%capture
# %%shell
jupyter nbconvert --to html /content/shap_values.ipynb
